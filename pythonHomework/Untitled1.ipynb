# %%
import spacy

# %%
nlp = spacy.cli.download("en_core_web_lg")
# Out:
# Collecting en-core-web-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.8.0/en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 33.5 MB/s  0:00:110m eta 0:00:010:00:01
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load("en_core_web_lg")
filepath = 'hughes-txt/sixteen.txt'
f = open(filepath, 'r', encoding='utf8').read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 nlp = spacy.load("en_core_web_lg")
#       2 filepath = 'hughes-txt/sixteen.txt'
#       3 f = open(filepath, 'r', encoding='utf8').read()
#
# NameError: name 'spacy' is not defined

# %%
nlp = spacy.load("en_core_web_lg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 nlp = spacy.load("en_core_web_lg")
#
# NameError: name 'spacy' is not defined

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_lg")

# %%
import spacy
nlp = spacy.cli.download("en_core_web_lg")
nlp = spacy.load("en_core_web_lg")
filepath = 'hughes-txt/sixteen.txt'
f = open(filepath, 'r', encoding='utf8').read()
# Out:
# Collecting en-core-web-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.8.0/en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 29.3 MB/s  0:00:120m eta 0:00:010:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       3 nlp = spacy.load("en_core_web_lg")
#       4 filepath = 'hughes-txt/sixteen.txt'
# ----> 5 f = open(filepath, 'r', encoding='utf8').read()
#
# File ~/Documents/GitHub/Portfolio-210/pythonHomework/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# --> 346 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hughes-txt/sixteen.txt'

# %%
import spacy
nlp = spacy.load("en_core_web_lg")
filepath = 'hughes-txt/sixteen.txt'
f = open(filepath, 'r', encoding='utf8').read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 nlp = spacy.load("en_core_web_lg")
#       3 filepath = 'hughes-txt/sixteen.txt'
# ----> 4 f = open(filepath, 'r', encoding='utf8').read()
#
# File ~/Documents/GitHub/Portfolio-210/pythonHomework/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# --> 346 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hughes-txt/sixteen.txt'

# %%
nlp = spacy.load("en_core_web_lg")
filepath = 'hughes-txt/sixteen.txt'
f = open(filepath, 'r', encoding='utf8').read()
spacyRead = nlp(f)
for token in spacyRead:
    print(token.text, "---->", token.pos_, ":::::", token.lemma_)
spacy.explain("DET")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 nlp = spacy.load("en_core_web_lg")
#       2 filepath = 'hughes-txt/sixteen.txt'
# ----> 3 f = open(filepath, 'r', encoding='utf8').read()
#       4 spacyRead = nlp(f)
#       5 for token in spacyRead:
#
# File ~/Documents/GitHub/Portfolio-210/pythonHomework/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# --> 346 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hughes-txt/sixteen.txt'

# %%
nlp = spacy.load("en_core_web_lg")
filepath = 'hughes-txt/sixteen.txt'
f = open(filepath, 'r', encoding='utf8').read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 nlp = spacy.load("en_core_web_lg")
#       2 filepath = 'hughes-txt/sixteen.txt'
# ----> 3 f = open(filepath, 'r', encoding='utf8').read()
#
# File ~/Documents/GitHub/Portfolio-210/pythonHomework/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# --> 346 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hughes-txt/sixteen.txt'
